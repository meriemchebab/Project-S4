# %%
import plotly.graph_objs as go
import numpy as np

with open(r'C:\Users\hp\Desktop\Project\Project-S4\files\CRM-polar-G2SG1-2019.atn',"r") as file:
        # Read all lines
    
    degree = []
    for line in file:
        try :
            if (float(line)):
                
                degree.append(float(line))
        except ValueError:
            pass
        
    # Create the angle valeur[the index in the list]
        theta = np.array(len(degree))
        
fig = go.Figure(
        data=go.Scatterpolar(
            r=degree,  # Radial values (the degree values from the file)
            theta=theta,  # Angular values (indices of the degree list)
            mode='lines',  # how we want to plot it
            name='Sensor Data' ) 
    )
    
fig.show()

# %%
import plotly.graph_objs as go
import numpy as np

with open(r'C:\Users\hp\Desktop\Project\Project-S4\files\CRMG2SG12019.atn',"r") as file:
        # Read all lines
    
    degree = []
    for line in file:
        try :
            if (float(line)):
                
                degree.append(float(line))
        except ValueError:
            pass
        
    # Create the angle valeur[the index in the list]
        theta = np.array(range(len(degree)))
        
fig = go.Figure(
        data=go.Scatterpolar(
            r=degree,  # Radial values (the degree values from the file)
            theta=theta,  # Angular values (indices of the degree list)
            mode='lines',  # how we want to plot it
            name='Sensor Data' ) 
    )
    
fig.show()
